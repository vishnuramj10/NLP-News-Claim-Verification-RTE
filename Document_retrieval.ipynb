# %% [markdown]
# # Is this Real? News Claim Verification Through Recognizing Textual Entailment
#
# Goal : The Project aims to develop a news claim check detector utilizing multiple news articles and claims associated with the news articles. Our dataset will primarily consist of multiple claims to a news article having different labels of Entailment, Contradiction and Neutral. The final model will be able to classify a given claim to the above set of labels by referring to the abundance articles. The Project follows a Knowledge Based style which has the following components:
#
# 1/ Document Retrieval
#
# 2/ Sentence Retrieval
#
# 3/ Claim Verification
#
# The **Document Retrieval** step has already been implemented to retrieve a npz file which contains document sparse matrix and its related metadata which has been used in this script.

# %%
import pandas as pd

# %%
df = pd.read_parquet("data_docmuent_retrieval")

# %%
df.rename({'Documents' : 'text'}, axis = 1, inplace = True)
df['text'] = df['text'].str.strip()
len(df)
# Out:
# 100000

# %%
df.drop_duplicates(subset = ['text'], inplace = True)
df['id'] = range(1, len(df) + 1)
df = df[['id', 'text']].copy()
df['id'] = df['id'].astype('str')
df.head()
# Out:
#    id                                               text
# 17  1  Whoever digs a pit will fall into it; if someo...
# 26  2  Photo: Kagin's Image 1 of / 11 Caption Close I...
# 35  3  The Chinese embassy in Australia has attacked ...
# 39  4  Back to Industry National Turkey Federation Re...
# 49  5  Hirsutes you: Women are more attracted to men ...

# %%
len(df)
# Out:
# 11149

# %%
result = df.to_dict(orient='records')

import json

# Write the result to a file
output_file_path = 'output.json'
with open(output_file_path, 'w') as output_file:
    for item in result:
        json.dump(item, output_file)
        output_file.write('\n')

print(f"Data has been written to {output_file_path}")
# Out:
# Data has been written to output.json

# %%
df1 = pd.read_parquet("data_document_retrieval")

# %%
df1.head()
# Out:
#                                             Documents  \
# 17                                           Whoev...
# 13                                           Whoev...
# 14                                           Whoev...
# 16                                           Whoev...
# 10                                           Whoev...
#
#                                                 Claim          label
# 17  A complaint has been filed against the judge w...        Neutral
# 13  He ordered Josten Bundy to marry his girlfrien...     Entailment
# 14  It is revealed that at least one similar rulin...     Entailment
# 16  Josten Bundy was ordered by Rogers to marry hi...        Neutral
# 10            Judge Rogers is not a government actor.  Contradiction

# %%
df1['Claim'][17]
# Out:
# 'A complaint has been filed against the judge with the State Commission for Judicial Conduct.'

# %%
pip install git+https://github.com/facebookresearch/DrQA.git
# Out:
# Collecting git+https://github.com/facebookresearch/DrQA.git
#   Cloning https://github.com/facebookresearch/DrQA.git to /tmp/pip-req-build-8wcxdj15
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/DrQA.git /tmp/pip-req-build-8wcxdj15
#   Resolved https://github.com/facebookresearch/DrQA.git to commit 6d7c1b7087b86cfe9bdf84a279adb58dceada3cd
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from drqa==0.1.0) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from drqa==0.1.0) (1.2.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from drqa==0.1.0) (2.3.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from drqa==0.1.0) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from drqa==0.1.0) (4.66.1)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from drqa==0.1.0) (3.9.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from drqa==0.1.0) (1.11.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from drqa==0.1.0) (3.8.1)
# Collecting elasticsearch (from drqa==0.1.0)
#   Downloading elasticsearch-8.11.0-py3-none-any.whl (412 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.6/412.6 kB 7.5 MB/s eta 0:00:00
# Collecting pexpect==4.2.1 (from drqa==0.1.0)
#   Downloading pexpect-4.2.1-py2.py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect==4.2.1->drqa==0.1.0) (0.7.0)
# Collecting elastic-transport<9,>=8 (from elasticsearch->drqa==0.1.0)
#   Downloading elastic_transport-8.10.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->drqa==0.1.0) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->drqa==0.1.0) (1.3.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->drqa==0.1.0) (0.2.12)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->drqa==0.1.0) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.26.2 in /usr/local/lib/python3.10/dist-packages (from elastic-transport<9,>=8->elasticsearch->drqa==0.1.0) (2.0.7)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from elastic-transport<9,>=8->elasticsearch->drqa==0.1.0) (2023.11.17)
# Building wheels for collected packages: drqa
#   Building wheel for drqa (setup.py) ... done
#   Created wheel for drqa: filename=drqa-0.1.0-py3-none-any.whl size=48412 sha256=681f77a977e9dd93eb295be28ae81cc33862e4676a8fbcce0c01540b983ad724
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yz1wkitr/wheels/66/d5/c9/ec057a271680ae2d0bfd3020f330064d895c07bc2862ba183b
# Successfully built drqa
# Installing collected packages: pexpect, elastic-transport, elasticsearch, drqa
#   Attempting uninstall: pexpect
#     Found existing installation: pexpect 4.9.0
#     Uninstalling pexpect-4.9.0:
#       Successfully uninstalled pexpect-4.9.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# ipython 7.34.0 requires pexpect>4.3; sys_platform != "win32", but you have pexpect 4.2.1 which is incompatible.
# Successfully installed drqa-0.1.0 elastic-transport-8.10.0 elasticsearch-8.11.0 pexpect-4.2.1

# %%
# Out:
# ['data', 'indices', 'indptr', 'shape', 'metadata']
# Array 1:
# []
#
# Array 2:
# []
#
# Array 3:
# [0 0 0 ... 0 0 0]
#
# Array 4:
# [16777216        2]
